# %% [markdown]
# #Solutions stationnaires de l'équation de D'Alembert
#
# L'équation de D'Alembert 1D décrit les ondes d'un grand nombre de modèles physiques : oscillations longitudinales d'un barreau élastique, oscillations transversales d'une corde tendue, ondes sonores, etc. Cette équation s'écrit :
# $${\partial^2 \psi \over \partial t^2} (x,t)= c^2{\partial^2 \psi \over \partial x^2} (x,t) \;.$$
# Une solution stationnaire peut être vue comme la superposition de deux ondes progressives monochromatiques de même amplitude se propageant en sens contraire, comme par exemple :
# \begin{eqnarray} \psi(x,t) & =& A \, \cos(k\, x - \omega\, t) + A \, \cos(k\, x + \omega \, t) \cr
# &=& 2\, A\, \cos(k\, x) \, \cos(\omega\,t)\;.
# \end{eqnarray}
# Le programme ci-dessous illustre cette superposition.

# %% [markdown]
# ![AnimOnde-stationnaire.gif](data:image/gif;base64,...)

# %% [markdown]
# Exécutez cette première partie du code pour définir les fonctions !

# %%
import numpy as np
import matplotlib.pyplot as plt

def zfi(x,le=2):
    miss=le-len(str(x))
    a='0'*miss+str(x)
    return a

def animationboth(name):
    acont=np.linspace(0,L,501);
    t=0; 
    dt=T/Nt
    for i in range(0,Nt+1):
        title=name+" i="+zfi(i)
        titlefig=name
        print(title)
        fig=plt.figure(1,figsize=(7,4))
        plt.xlabel('x',fontsize=16 )
        plt.ylabel(r'$\psi$',fontsize=16)
        plt.title(titlefig,fontsize=16)
        # signal
        t=dt*i;
        xicont=signal(acont,t)
        xileft=signalleft(acont,t)
        xiright=signalright(acont,t)
        plt.plot(acont,xicont,color='black',linewidth=3)
        plt.plot(acont,xileft,color='green',linewidth=3)
        plt.plot(acont,xiright,color='red',linewidth=3)
        plt.xlim(0,L)
        plt.ylim(ymin,ymax)
        namei=name+zfi(i)+'.png';
        plt.grid(color='black', axis='y', linestyle='-', linewidth=1)        
        plt.grid(color='black', axis='x', linestyle='-', linewidth=1)        
        plt.savefig(namei)
        plt.show()
        plt.close()
 
def leftsin(a,k):
    al=a[a<=0]; ar=0*a[a>0];
    fl=-np.sin(k*al);
    f=np.concatenate((fl,ar))
    return f

def rightsin(a,k):
    al=0*a[a<=0]; ar=a[a>0];
    fr=np.sin(k*ar);
    f=np.concatenate((al,fr))
    return f

# %% [markdown]
# Les paramètres suivants de la simulation peuvent être modifiés :
# *   $L$ : longueur de l'intervalle
# *   $c$ : vitesse de propagation
# *   $Nt$ : nombre d'images
# *   $k$ : nombre d'onde
# *   $T$ : temps de simulation
#
#
# Exécutez le programme ci-dessous et placez-vous en bas de la page pour voir l'animation !

# %%
L=10; c=1; Nt=82; k=4*np.pi/L; T=2*L/c; 
sc=.9*L/20 # scaling 
omega=k*c;
ymin=-1; ymax=1;
# signal 
def signal(a,t):
    xi=.5*rightsin(-L+a+c*t,k)+.5*leftsin(a-c*t,k)
    return xi
def signalleft(a,t):
    xi=.5*rightsin(-L+a+c*t,k)
    return xi
def signalright(a,t):
    xi=.5*leftsin(a-c*t,k)
    return xi
animationboth("Onde-stationnaire")
# Out:
# Onde-stationnaire i=00
# Onde-stationnaire i=01
# Onde-stationnaire i=02
# Onde-stationnaire i=03
# Onde-stationnaire i=04
# Onde-stationnaire i=05
# Onde-stationnaire i=06
# Onde-stationnaire i=07
# Onde-stationnaire i=08
# Onde-stationnaire i=09
# Onde-stationnaire i=10
# Onde-stationnaire i=11
# Onde-stationnaire i=12
# Onde-stationnaire i=13
# Onde-stationnaire i=14
# Onde-stationnaire i=15
# Onde-stationnaire i=16
# Onde-stationnaire i=17
# Onde-stationnaire i=18
# Onde-stationnaire i=19
# Onde-stationnaire i=20
# Onde-stationnaire i=21
# Onde-stationnaire i=22
# Onde-stationnaire i=23
# Onde-stationnaire i=24
# Onde-stationnaire i=25
# Onde-stationnaire i=26
# Onde-stationnaire i=27
# Onde-stationnaire i=28
# Onde-stationnaire i=29
# Onde-stationnaire i=30
# Onde-stationnaire i=31
# Onde-stationnaire i=32
# Onde-stationnaire i=33
# Onde-stationnaire i=34
# Onde-stationnaire i=35
# Onde-stationnaire i=36
# Onde-stationnaire i=37
# Onde-stationnaire i=38
# Onde-stationnaire i=39
# ...
